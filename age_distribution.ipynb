# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load the dataset
df = pd.read_csv(r'C:\Project\myProject\Prognozowanie-rezygnacji-klientów-dla-firmy-telekomunikacyjnej\internet_service_churn.csv')

# Plotting the 'subscription_age' distribution
sns.histplot(df['subscription_age'], kde=True)
plt.title('Subscription Age Distribution')
plt.show()
